# %%
from datetime import date, timedelta

class Person:
    
    def __init__(self, first_name, last_name, date_of_birth):
        self.first_name = first_name
        self.last_name = last_name
        self.date_of_birth = date_of_birth
        self.age = self.Calculate_Age()
        
    def __str__(self):
        return f" My name is {self.first_name} {self.last_name} and date of birth year is {self.date_of_birth} and age is {self.age}"
    
    def Calculate_Age(self):
        # timedelta(days=365.2425)
        age = (date.today().year - self.date_of_birth)
        return age
    
class Sort_Person():
    
    def __init__(self, person_list):
        # super().__init__(first_name,last_name,date_of_birth)
        self.person_list = person_list
        
    def get_person_by_first_name(self, first_name):
        for person in self.person_list:
            if person.first_name == first_name:
                return person
            
    def get_person_by_last_name(self, last_name):
        for person in self.person_list:
            if person.last_name == last_name:
                return person
      
    def __str__(self):
        for person in self.person_list:
            print(person)
        return ""
    
    def Sort_By_First_Name_Ascending(self):
        list_name = []
        sorted_person = []
        for person in self.person_list:
            list_name.append(person.first_name)
        list_name.sort()
        for first_name in list_name:
            print(self.get_person_by_first_name(first_name))
            sorted_person.append(self.get_person_by_first_name(first_name))
        self.person_list = sorted_person
        return None
    
    def Sort_By_Last_Name_Ascending(self):
        list_name = []
        sorted_person = []
        for person in self.person_list:
            list_name.append(person.last_name)
        list_name.sort()
        for last_name in list_name:
            # print(self.get_person_by_first_name(first_name))
            sorted_person.append(self.get_person_by_last_name(last_name))
        self.person_list = sorted_person
        return None
    
        
    def Sort_By_First_Name_Descending(self):
        list_name = []
        sorted_person = []
        for person in self.person_list:
            list_name.append(person.first_name)
        list_name.sort(reverse=True)
        for first_name in list_name:
            #print(self.get_person_by_first_name(first_name))
            sorted_person.append(self.get_person_by_first_name(first_name))
        self.person_list = sorted_person
        return None
    
    
    
    def Sort_By_Last_Name_Descending(self):
        list_name = []
        sorted_person = []
        for person in self.person_list:
            list_name.append(person.last_name)
        list_name.sort(reverse=True)
        for last_name in list_name:
            #print(self.get_person_by_last_name(last_name))
            sorted_person.append(self.get_person_by_last_name(last_name))
        self.person_list = sorted_person
        return None
    
    def Sort_By_Age_Ascending(self):
        return none
    
    def Sort_By_Age_Descending(self):
        return none
    
p1 = Person('yash', 'mishra', 1991)
p2 = Person('parag', 'gunjal', 1993)
p3 = Person('abrar', 'abu', 1996)
person_list = []
person_list.append(p1)
person_list.append(p2)
person_list.append(p3)
sort_person = Sort_Person(person_list)
print("before sorting")
print(sort_person)
print("after sorting first name asc")
sort_person.Sort_By_First_Name_Ascending()
print("after sorting first name desc")
sort_person.Sort_By_First_Name_Descending()
print(sort_person)
print("after sorting last name asc")
sort_person.Sort_By_Last_Name_Ascending()
print(sort_person)
print("after sorting last name desc")
sort_person.Sort_By_Last_Name_Descending()
print(sort_person)
# sort_first_name = sorted(p, key=lambda p: p.first_name)
# print(sort_first_name)
# print(sorted(p,reverse=True))
# Out:
# before sorting
#  My name is yash mishra and date of birth year is 1991 and age is 31
#  My name is parag gunjal and date of birth year is 1993 and age is 29
#  My name is abrar abu and date of birth year is 1996 and age is 26
#
# after sorting first name asc
#  My name is abrar abu and date of birth year is 1996 and age is 26
#  My name is parag gunjal and date of birth year is 1993 and age is 29
#  My name is yash mishra and date of birth year is 1991 and age is 31
# after sorting first name desc
#  My name is yash mishra and date of birth year is 1991 and age is 31
#  My name is parag gunjal and date of birth year is 1993 and age is 29
#  My name is abrar abu and date of birth year is 1996 and age is 26
#
# after sorting last name asc
#  My name is abrar abu and date of birth year is 1996 and age is 26
#  My name is parag gunjal and date of birth year is 1993 and age is 29
#  My name is yash mishra and date of birth year is 1991 and age is 31
#
# after sorting last name desc
#  My name is yash mishra and date of birth year is 1991 and age is 31
#  My name is parag gunjal and date of birth year is 1993 and age is 29
#  My name is abrar abu and date of birth year is 1996 and age is 26
